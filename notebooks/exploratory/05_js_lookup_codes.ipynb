# %%
import pandas as pd
pd.set_option("display.max_colwidth", 0)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_lu=pd.read_csv('../../data/EXTR_LookUp.csv')
def LU_item(df,number):
    """Put in name of your Look up data frame then description number and it will use this Data frame. 
    To give the values associated with it and its descriptions from least to greatest"""
    lu_list=df[df["LUType"]== number]
    return lu_list.sort_values("LUItem", ascending=True)

# %%
property_type=LU_item(df_lu,6)
property_type
# Out:
#       LUType  LUItem                                       LUDescription
# 1002  6       1       None
# 1009  6       2       Warranty Deed
# 1019  6       3       Statutory Warranty Deed
# 1020  6       4       Special Warranty Deed
# 1021  6       5       Corporate Warranty Deed
# 1022  6       6       Assumption Warranty Deed
# 1023  6       7       Grant Deed
# 1024  6       8       Contract (equity)
# 1025  6       9       Contract (installment)
# 1003  6       10      Real Estate Contract
# 1004  6       11      Purchaser's Assignment
# 1005  6       13      Seller's Assignment
# 1006  6       15      Quit Claim Deed
# 1007  6       18      Trustees' Deed
# 1008  6       19      Executor's Deed
# 1010  6       20      Fiduciary Deed
# 1011  6       21      Sheriff's Deed
# 1012  6       22      Bargain and Sales Deed
# 1013  6       23      Receivers Deed
# 1014  6       24      Deed of Personal Rep
# 1015  6       25      Judgment Per Stipulation
# ...

# %%
sale_reason=LU_item(df_lu,5)
sale_reason
# Out:
#      LUType  LUItem                                       LUDescription
# 945  5       1       None
# 956  5       2       Assumption
# 957  5       3       Mortgage Assumption
# 958  5       4       Foreclosure
# 959  5       5       Trust
# 960  5       6       Executor-to admin guardian
# 961  5       7       Testamentary Trust
# 962  5       8       Estate Settlement
# 963  5       9       Settlement
# 946  5       10      Property Settlement
# 947  5       11      Divorce Settlement
# 948  5       12      Tenancy Partition
# 949  5       13      Community Prop Established
# 950  5       14      Partial Int - love,aff,gft
# 951  5       15      Easement
# 952  5       16      Correction (refiling)
# 953  5       17      Trade
# 954  5       18      Other
# 955  5       19      Quit Claim Deed - gift/full or part interest

# %%
principal_use=LU_item(df_lu,2)
principal_use
# Out:
#      LUType  LUItem                                       LUDescription
# 804  2       1       AGRICULTURAL
# 807  2       2       CONDOMINIUM
# 808  2       3       RECREATIONAL
# 809  2       4       APT(4+ UNITS)
# 810  2       5       INDUSTRIAL
# 811  2       6       RESIDENTIAL
# 812  2       7       COMMERCIAL
# 813  2       8       MOBILE HOME
# 814  2       9       TIMBER
# 805  2       10      OTHER
# 806  2       11      COMMERCIAL/INDUSTRIAL

# %%
propert_class=LU_item(df_lu,4)
propert_class
# Out:
#      LUType  LUItem                                       LUDescription
# 861  4       1       C/I-Land only
# 862  4       2       C/I-Imp prop; no condo/MH
# 863  4       3       C/I-Condominium
# 864  4       4       C/I-Air rights only
# 865  4       5       C/I-Imp prop excl air rights
# 866  4       6       C/I-Land or bldg; no split
# 867  4       7       Res-Land only
# 868  4       8       Res-Improved property
# 869  4       9       Res or C/I-Mobile Home

# %%
vis_data=pd.DataFrame({'Sale Instrument Value':['15', '3','26','24','2','27','4''22','18','21','19','20','23','1'] ,'Percentage of Sales 2019 Data Zero values':[77.54189944134077426187, 14.018621973929237, 2.5549348230912474, 1.9888268156424582, 1.728119180633147, 0.74487895716946,0.6927374301675978, 0.3128491620111732, 
                                                                                                                                                 0.260707635009311 ,0.0670391061452514,0.059590316573556804,0.014897579143389201,0.0074487895716946004]})

ax = vis_data.plot.bar(x='Sale Instrument Value', y='Percentage of Sales 2019 Data Zero values', rot=0, title='Percentage of zero values by SaleInstrument Value')
ax.set_ylabel('% of Sales 2019 Data Zero values');
